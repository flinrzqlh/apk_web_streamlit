# %% [markdown]
# # ***CRAWLING DATA TWITTER***

# %%
#@title Twitter Auth Token

twitter_auth_token = 'put twt auth token here' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:4 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,160 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,602 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,326 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,387 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,449 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,595 kB]
# Fetched 18.8 MB in 3s (5,892 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.18).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:4 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:8 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Ign:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:12 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Get:13 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [9,254 B]
# Fetched 21.4 kB in 2s (14.2 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 51 not upgraded.
# Need to get 31.8 MB of archives.
# After this operation, 197 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.18.0-1nodesource1 [31.8 MB]
# Fetched 31.8 MB in 1s (61.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.18.0-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.18.0-1nodesource1) ...
# Setting up nodejs (20.18.0-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.18.0

# %%
# Crawl Data

filename = 'iisma.csv'
search_keyword = 'iisma since:2023-04-01 until:2024-04-01 lang:id'
limit = 300

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/iisma.csv, renaming to ./tweets-data/iisma.old.csv
#
# -- Scrolling... (1) (2)
# Filling in keywords: iisma since:2023-04-01 until:2024-04-01 lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 14
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 29
#
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 35
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 53
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 73
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 93
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 106
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 122
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 138
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 153
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 171
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 190
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 209
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 226
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 245
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 265
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 282
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 299
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/iisma.csv
# Total tweets saved: 319
#
# --Taking a break, waiting for 10 seconds...
# Got 319 tweets, done scrolling...
# ⠙

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1774585323932237911  Sun Mar 31 23:51:26 +0000 2024               1
# 1    1774554725612126642  Sun Mar 31 21:49:50 +0000 2024               0
# 2    1774542428198068592  Sun Mar 31 21:00:58 +0000 2024               0
# 3    1774376989803372956  Sun Mar 31 20:45:35 +0000 2024               0
# 4    1774538359198912620  Sun Mar 31 20:44:48 +0000 2024               0
# ..                   ...                             ...             ...
# 314  1773764418498863356  Fri Mar 29 18:11:20 +0000 2024               0
# 315  1773774539471884725  Fri Mar 29 18:09:40 +0000 2024               0
# 316  1773774351785214010  Fri Mar 29 18:09:23 +0000 2024               0
# 317  1773773854781198513  Fri Mar 29 18:06:56 +0000 2024               0
# 318  1773773637189079286  Fri Mar 29 18:06:04 +0000 2024               0
#
#                                              full_text               id_str  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...  1774585323932237911
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...  1774554725612126642
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...  1774542428198068592
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha   1774538556268220656
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...  1774538359198912620
# ..                                                 ...                  ...
# 314                          @sleketeprikitiw heboh lu  1773774959967654191
# 315                             ok ak mau jd collector  1773774539471884725
# 316                   @tabibiba KA TABI INI BELI DMNAA  1773774468252619039
# 317  Pengen punya sirkel yang lolos IISMA atau mini...  1773773854781198513
# 318  ehh salah satu iisma awardee favorit gue kok n...  1773773637189079286
#
#     image_url in_reply_to_screen_name lang               location  \
# 0         NaN                     NaN   in    Tembalang, Semarang
# 1         NaN                     NaN   in       DMs always open!
# 2         NaN                     NaN   in                    NaN
# 3         NaN                 akuadn_   in             lagi di 🇫🇷
# 4         NaN                     NaN   in                    NaN
# ..        ...                     ...  ...                    ...
# 314       NaN         sleketeprikitiw   in                    NaN
# 315       NaN                     NaN   in          unlabeled acc
# 316       NaN                tabibiba   in          unlabeled acc
# 317       NaN                     NaN   in  Yogyakarta, Indonesia
# 318       NaN                     NaN   in            she/they 21
#
#      quote_count  reply_count  retweet_count  \
# 0              0            0              0
# 1              0            0              0
# 2              0            1              0
# 3              0            0              0
# 4              0            0              1
# ..           ...          ...            ...
# 314            0            1              0
# 315            0            0              0
# 316            0            1              0
# 317            0            0              0
# 318            0            1              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/campusnesiacoid/status/177458532...           4831061174
# 1    https://x.com/Starquisitor/status/177455472561...  1414932409678647301
# 2    https://x.com/r0salm0n/status/1774542428198068592  1359150939601567754
# 3    https://x.com/laloyyy_/status/1774538556268220656  1147476441644191745
# 4    https://x.com/springirlss/status/1774538359198...  1760896638120550400
# ..                                                 ...                  ...
# 314   https://x.com/rukipar/status/1773774959967654191  1139799461834551297
# 315  https://x.com/calcaros/status/1773774539471884725  1640009291028660226
# 316  https://x.com/calcaros/status/1773774468252619039  1640009291028660226
# 317  https://x.com/gezabayusans/status/177377385478...  1255537534030864384
# 318  https://x.com/psikobagiduo/status/177377363718...  1561926421626650624
#
#             username
# 0    campusnesiacoid
# 1       Starquisitor
# 2           r0salm0n
# 3           laloyyy_
# 4        springirlss
# ..               ...
# 314          rukipar
# 315         calcaros
# 316         calcaros
# 317     gezabayusans
# 318     psikobagiduo
#
# [319 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 319.

# %% [markdown]
# # ***PRE-PROCESSING DATA***

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(data)
#
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1774585323932237911  Sun Mar 31 23:51:26 +0000 2024               1
# 1    1774554725612126642  Sun Mar 31 21:49:50 +0000 2024               0
# 2    1774542428198068592  Sun Mar 31 21:00:58 +0000 2024               0
# 3    1774376989803372956  Sun Mar 31 20:45:35 +0000 2024               0
# 4    1774538359198912620  Sun Mar 31 20:44:48 +0000 2024               0
# ..                   ...                             ...             ...
# 314  1773764418498863356  Fri Mar 29 18:11:20 +0000 2024               0
# 315  1773774539471884725  Fri Mar 29 18:09:40 +0000 2024               0
# 316  1773774351785214010  Fri Mar 29 18:09:23 +0000 2024               0
# 317  1773773854781198513  Fri Mar 29 18:06:56 +0000 2024               0
# 318  1773773637189079286  Fri Mar 29 18:06:04 +0000 2024               0
#
#                                              full_text               id_str  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...  1774585323932237911
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...  1774554725612126642
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...  1774542428198068592
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha   1774538556268220656
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...  1774538359198912620
# ..                                                 ...                  ...
# 314                          @sleketeprikitiw heboh lu  1773774959967654191
# 315                             ok ak mau jd collector  1773774539471884725
# 316                   @tabibiba KA TABI INI BELI DMNAA  1773774468252619039
# 317  Pengen punya sirkel yang lolos IISMA atau mini...  1773773854781198513
# 318  ehh salah satu iisma awardee favorit gue kok n...  1773773637189079286
#
#     image_url in_reply_to_screen_name lang               location  \
# 0         NaN                     NaN   in    Tembalang, Semarang
# 1         NaN                     NaN   in       DMs always open!
# 2         NaN                     NaN   in                    NaN
# 3         NaN                 akuadn_   in             lagi di 🇫🇷
# 4         NaN                     NaN   in                    NaN
# ..        ...                     ...  ...                    ...
# 314       NaN         sleketeprikitiw   in                    NaN
# 315       NaN                     NaN   in          unlabeled acc
# 316       NaN                tabibiba   in          unlabeled acc
# 317       NaN                     NaN   in  Yogyakarta, Indonesia
# 318       NaN                     NaN   in            she/they 21
#
#      quote_count  reply_count  retweet_count  \
# 0              0            0              0
# 1              0            0              0
# 2              0            1              0
# 3              0            0              0
# 4              0            0              1
# ..           ...          ...            ...
# 314            0            1              0
# 315            0            0              0
# 316            0            1              0
# 317            0            0              0
# 318            0            1              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/campusnesiacoid/status/177458532...           4831061174
# 1    https://x.com/Starquisitor/status/177455472561...  1414932409678647301
# 2    https://x.com/r0salm0n/status/1774542428198068592  1359150939601567754
# 3    https://x.com/laloyyy_/status/1774538556268220656  1147476441644191745
# 4    https://x.com/springirlss/status/1774538359198...  1760896638120550400
# ..                                                 ...                  ...
# 314   https://x.com/rukipar/status/1773774959967654191  1139799461834551297
# 315  https://x.com/calcaros/status/1773774539471884725  1640009291028660226
# 316  https://x.com/calcaros/status/1773774468252619039  1640009291028660226
# 317  https://x.com/gezabayusans/status/177377385478...  1255537534030864384
# 318  https://x.com/psikobagiduo/status/177377363718...  1561926421626650624
#
#             username
# 0    campusnesiacoid
# 1       Starquisitor
# 2           r0salm0n
# 3           laloyyy_
# 4        springirlss
# ..               ...
# 314          rukipar
# 315         calcaros
# 316         calcaros
# 317     gezabayusans
# 318     psikobagiduo
#
# [319 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      319 non-null    int64
#  1   created_at               319 non-null    object
#  2   favorite_count           319 non-null    int64
#  3   full_text                319 non-null    object
#  4   id_str                   319 non-null    int64
#  5   image_url                27 non-null     object
#  6   in_reply_to_screen_name  166 non-null    object
#  7   lang                     319 non-null    object
#  8   location                 144 non-null    object
#  9   quote_count              319 non-null    int64
#  10  reply_count              319 non-null    int64
#  11  retweet_count            319 non-null    int64
#  12  tweet_url                319 non-null    object
#  13  user_id_str              319 non-null    int64
#  14  username                 319 non-null    object
# dtypes: int64(7), object(8)
# memory usage: 37.5+ KB

# %%
data.drop_duplicates(subset='full_text', keep = 'first', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      319 non-null    int64
#  1   created_at               319 non-null    object
#  2   favorite_count           319 non-null    int64
#  3   full_text                319 non-null    object
#  4   id_str                   319 non-null    int64
#  5   image_url                27 non-null     object
#  6   in_reply_to_screen_name  166 non-null    object
#  7   lang                     319 non-null    object
#  8   location                 144 non-null    object
#  9   quote_count              319 non-null    int64
#  10  reply_count              319 non-null    int64
#  11  retweet_count            319 non-null    int64
#  12  tweet_url                319 non-null    object
#  13  user_id_str              319 non-null    int64
#  14  username                 319 non-null    object
# dtypes: int64(7), object(8)
# memory usage: 37.5+ KB

# %%
df = pd.DataFrame(data['full_text'])
df.head(319)
# Out:
#                                              full_text
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
# [319 rows x 1 columns]

# %% [markdown]
# Cleaning

# %%
import re
import string
import nltk

def remove_URL(tweet):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', tweet)

def remove_html(tweet):
    html = re.compile(r'<.*?>')
    return html.sub(r'', tweet)

def remove_emoji(tweet):
    emoji_pattern = re.compile("["
      u"\U0001F600-\U0001F64F"
      u"\U0001F300-\U0001F5FF"
      u"\U0001F680-\U0001F6FF"
      u"\U0001F1E0-\U0001F1FF"
      "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', tweet)

def remove_angka(tweet):
    tweet = re.sub(r'\d+', '', tweet)
    return tweet

def remove_symbols(tweet):
    tweet = re.sub(r'[^a-zA-Z0-9\s]', '', tweet)
    return tweet

df['cleaning'] = df['full_text'].apply(lambda x: remove_URL(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_html(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_emoji(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_symbols(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_angka(x))

df.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
# [319 rows x 2 columns]

# %% [markdown]
# CASE FOLDING

# %%
def case_folding(text):
    if isinstance(text, str):
        lowercase_text = text.lower()
        return lowercase_text
    else:
        return text

df['case_folding'] = df['cleaning'].apply(case_folding)
df.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                           case_folding
# 0    melalui program iisma mahasiswi psikologi univ...
# 1    hooo ept sekarang ada joki dan pemalsuan serti...
# 2    btw mo cerita kmrn pas volunteer sumpeh relawa...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    kalo ga iisma ya s di ptln tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba ka tabi ini beli dmnaa
# 317  pengen punya sirkel yang lolos iisma atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
# [319 rows x 3 columns]

# %% [markdown]
# TOKENIZATION

# %%
def tokenize(text):
    tokens = text.split()
    return tokens

df['tokenize'] = df['case_folding'].apply(tokenize)
df.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                           case_folding  \
# 0    melalui program iisma mahasiswi psikologi univ...
# 1    hooo ept sekarang ada joki dan pemalsuan serti...
# 2    btw mo cerita kmrn pas volunteer sumpeh relawa...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    kalo ga iisma ya s di ptln tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba ka tabi ini beli dmnaa
# 317  pengen punya sirkel yang lolos iisma atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               tokenize
# 0    [melalui, program, iisma, mahasiswi, psikologi...
# 1    [hooo, ept, sekarang, ada, joki, dan, pemalsua...
# 2    [btw, mo, cerita, kmrn, pas, volunteer, sumpeh...
# 3      [akuadn, capek, ngejar, iisma, dibilang, gacha]
# 4    [kalo, ga, iisma, ya, s, di, ptln, tapi, kalo,...
# ..                                                 ...
# 314                       [sleketeprikitiw, heboh, lu]
# 315                       [ok, ak, mau, jd, collector]
# 316             [tabibiba, ka, tabi, ini, beli, dmnaa]
# 317  [pengen, punya, sirkel, yang, lolos, iisma, at...
# 318  [ehh, salah, satu, iisma, awardee, favorit, gu...
#
# [319 rows x 4 columns]

# %% [markdown]
# FILTERING/STOPWORD REMOVAL

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('indonesian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stop]

df['filtering/stopword removal'] = df['tokenize'].apply(lambda x: remove_stopwords(x))
df.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                           case_folding  \
# 0    melalui program iisma mahasiswi psikologi univ...
# 1    hooo ept sekarang ada joki dan pemalsuan serti...
# 2    btw mo cerita kmrn pas volunteer sumpeh relawa...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    kalo ga iisma ya s di ptln tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba ka tabi ini beli dmnaa
# 317  pengen punya sirkel yang lolos iisma atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               tokenize  \
# 0    [melalui, program, iisma, mahasiswi, psikologi...
# 1    [hooo, ept, sekarang, ada, joki, dan, pemalsua...
# 2    [btw, mo, cerita, kmrn, pas, volunteer, sumpeh...
# 3      [akuadn, capek, ngejar, iisma, dibilang, gacha]
# 4    [kalo, ga, iisma, ya, s, di, ptln, tapi, kalo,...
# ..                                                 ...
# 314                       [sleketeprikitiw, heboh, lu]
# 315                       [ok, ak, mau, jd, collector]
# 316             [tabibiba, ka, tabi, ini, beli, dmnaa]
# 317  [pengen, punya, sirkel, yang, lolos, iisma, at...
# 318  [ehh, salah, satu, iisma, awardee, favorit, gu...
#
#                             filtering/stopword removal
# 0    [program, iisma, mahasiswi, psikologi, univers...
# 1    [hooo, ept, joki, pemalsuan, sertifikat, yaa, ...
# 2    [btw, mo, cerita, kmrn, pas, volunteer, sumpeh...
# 3      [akuadn, capek, ngejar, iisma, dibilang, gacha]
# 4    [kalo, ga, iisma, ya, s, ptln, kalo, nya, sih,...
# ..                                                 ...
# 314                       [sleketeprikitiw, heboh, lu]
# 315                            [ok, ak, jd, collector]
# 316                  [tabibiba, ka, tabi, beli, dmnaa]
# 317  [pengen, sirkel, lolos, iisma, minimal, anak, ...
# 318  [ehh, salah, iisma, awardee, favorit, gue, ngi...
#
# [319 rows x 5 columns]

# %% [markdown]
# STEAMING DATA

# %%
# !pip install Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(text):
    return [stemmer.stem(word) for word in text]

df['steaming_data'] = df['filtering/stopword removal'].apply(lambda x: ' '.join(stem_text(x)))
df.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                           case_folding  \
# 0    melalui program iisma mahasiswi psikologi univ...
# 1    hooo ept sekarang ada joki dan pemalsuan serti...
# 2    btw mo cerita kmrn pas volunteer sumpeh relawa...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    kalo ga iisma ya s di ptln tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba ka tabi ini beli dmnaa
# 317  pengen punya sirkel yang lolos iisma atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               tokenize  \
# 0    [melalui, program, iisma, mahasiswi, psikologi...
# 1    [hooo, ept, sekarang, ada, joki, dan, pemalsua...
# 2    [btw, mo, cerita, kmrn, pas, volunteer, sumpeh...
# 3      [akuadn, capek, ngejar, iisma, dibilang, gacha]
# 4    [kalo, ga, iisma, ya, s, di, ptln, tapi, kalo,...
# ..                                                 ...
# 314                       [sleketeprikitiw, heboh, lu]
# 315                       [ok, ak, mau, jd, collector]
# 316             [tabibiba, ka, tabi, ini, beli, dmnaa]
# 317  [pengen, punya, sirkel, yang, lolos, iisma, at...
# 318  [ehh, salah, satu, iisma, awardee, favorit, gu...
#
#                             filtering/stopword removal  \
# 0    [program, iisma, mahasiswi, psikologi, univers...
# 1    [hooo, ept, joki, pemalsuan, sertifikat, yaa, ...
# 2    [btw, mo, cerita, kmrn, pas, volunteer, sumpeh...
# 3      [akuadn, capek, ngejar, iisma, dibilang, gacha]
# 4    [kalo, ga, iisma, ya, s, ptln, kalo, nya, sih,...
# ..                                                 ...
# 314                       [sleketeprikitiw, heboh, lu]
# 315                            [ok, ak, jd, collector]
# 316                  [tabibiba, ka, tabi, beli, dmnaa]
# 317  [pengen, sirkel, lolos, iisma, minimal, anak, ...
# 318  [ehh, salah, iisma, awardee, favorit, gue, ngi...
#
#                                          steaming_data
# 0    program iisma mahasiswi psikologi universitas ...
# 1    hooo ept joki palsu sertifikat yaa kalo kait p...
# 2    btw mo cerita kmrn pas volunteer sumpeh rawan ...
# 3               akuadn capek ngejar iisma bilang gacha
# 4            kalo ga iisma ya s ptln kalo nya sih hehe
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                                 ok ak jd collector
# 316                        tabibiba ka tabi beli dmnaa
# 317  ken sirkel lolos iisma minimal anak lpdp ndak ...
# 318  ehh salah iisma awardee favorit gue ngilang tw...
#
# [319 rows x 6 columns]

# %% [markdown]
# EXPORT PRE-PROCESSED DATA

# %%
df.to_csv('preproc.csv', encoding='utf8', index=False)

# %% [markdown]
# # ***LABELLING DATA***

# %%
import pandas as pd
import numpy as np

def load_data():
    data = pd.read_csv('preproc.csv')
    return data

data = load_data()
data.head(319)
# Out:
#                                              full_text  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3         @akuadn_ capek2 ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S2 di PTLN tapi kalo bisa 22n...
# ..                                                 ...
# 314                          @sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                   @tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               cleaning  \
# 0    Melalui Program IISMA Mahasiswi Psikologi Univ...
# 1    hooo EPT sekarang ada joki dan pemalsuan serti...
# 2    Btw mo cerita kmrn pas volunteer SUMPEH RELAWA...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    Kalo ga IISMA ya S di PTLN tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba KA TABI INI BELI DMNAA
# 317  Pengen punya sirkel yang lolos IISMA atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                           case_folding  \
# 0    melalui program iisma mahasiswi psikologi univ...
# 1    hooo ept sekarang ada joki dan pemalsuan serti...
# 2    btw mo cerita kmrn pas volunteer sumpeh relawa...
# 3            akuadn capek ngejar iisma dibilang gacha
# 4    kalo ga iisma ya s di ptln tapi kalo bisa nya ...
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                             ok ak mau jd collector
# 316                    tabibiba ka tabi ini beli dmnaa
# 317  pengen punya sirkel yang lolos iisma atau mini...
# 318  ehh salah satu iisma awardee favorit gue kok n...
#
#                                               tokenize  \
# 0    ['melalui', 'program', 'iisma', 'mahasiswi', '...
# 1    ['hooo', 'ept', 'sekarang', 'ada', 'joki', 'da...
# 2    ['btw', 'mo', 'cerita', 'kmrn', 'pas', 'volunt...
# 3    ['akuadn', 'capek', 'ngejar', 'iisma', 'dibila...
# 4    ['kalo', 'ga', 'iisma', 'ya', 's', 'di', 'ptln...
# ..                                                 ...
# 314                 ['sleketeprikitiw', 'heboh', 'lu']
# 315             ['ok', 'ak', 'mau', 'jd', 'collector']
# 316  ['tabibiba', 'ka', 'tabi', 'ini', 'beli', 'dmn...
# 317  ['pengen', 'punya', 'sirkel', 'yang', 'lolos',...
# 318  ['ehh', 'salah', 'satu', 'iisma', 'awardee', '...
#
#                             filtering/stopword removal  \
# 0    ['program', 'iisma', 'mahasiswi', 'psikologi',...
# 1    ['hooo', 'ept', 'joki', 'pemalsuan', 'sertifik...
# 2    ['btw', 'mo', 'cerita', 'kmrn', 'pas', 'volunt...
# 3    ['akuadn', 'capek', 'ngejar', 'iisma', 'dibila...
# 4    ['kalo', 'ga', 'iisma', 'ya', 's', 'ptln', 'ka...
# ..                                                 ...
# 314                 ['sleketeprikitiw', 'heboh', 'lu']
# 315                    ['ok', 'ak', 'jd', 'collector']
# 316        ['tabibiba', 'ka', 'tabi', 'beli', 'dmnaa']
# 317  ['pengen', 'sirkel', 'lolos', 'iisma', 'minima...
# 318  ['ehh', 'salah', 'iisma', 'awardee', 'favorit'...
#
#                                          steaming_data
# 0    program iisma mahasiswi psikologi universitas ...
# 1    hooo ept joki palsu sertifikat yaa kalo kait p...
# 2    btw mo cerita kmrn pas volunteer sumpeh rawan ...
# 3               akuadn capek ngejar iisma bilang gacha
# 4            kalo ga iisma ya s ptln kalo nya sih hehe
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                                 ok ak jd collector
# 316                        tabibiba ka tabi beli dmnaa
# 317  ken sirkel lolos iisma minimal anak lpdp ndak ...
# 318  ehh salah iisma awardee favorit gue ngilang tw...
#
# [319 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   full_text                   319 non-null    object
#  1   cleaning                    319 non-null    object
#  2   case_folding                319 non-null    object
#  3   tokenize                    319 non-null    object
#  4   filtering/stopword removal  319 non-null    object
#  5   steaming_data               319 non-null    object
# dtypes: object(6)
# memory usage: 15.1+ KB

# %%
df = pd.DataFrame(data['steaming_data'])
df.head(319)
# Out:
#                                          steaming_data
# 0    program iisma mahasiswi psikologi universitas ...
# 1    hooo ept joki palsu sertifikat yaa kalo kait p...
# 2    btw mo cerita kmrn pas volunteer sumpeh rawan ...
# 3               akuadn capek ngejar iisma bilang gacha
# 4            kalo ga iisma ya s ptln kalo nya sih hehe
# ..                                                 ...
# 314                           sleketeprikitiw heboh lu
# 315                                 ok ak jd collector
# 316                        tabibiba ka tabi beli dmnaa
# 317  ken sirkel lolos iisma minimal anak lpdp ndak ...
# 318  ehh salah iisma awardee favorit gue ngilang tw...
#
# [319 rows x 1 columns]

# %%
# !pip install nltk
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
data = SentimentIntensityAnalyzer()
labels = []
scores = []

for text in df['steaming_data']:
    sentiment_scores = data.polarity_scores(text)
    compound_score = sentiment_scores['compound']

    scores.append(compound_score)

    if compound_score > 0:
        labels.append('Positif')
    elif compound_score < 0:
        labels.append('Negatif')
    else:
        labels.append('Netral')

df['sentiment'] = labels
df['sentiment_score'] = scores

data = ['steaming_data', 'sentiment_score', 'sentiment']
data = df[data]

data.head(319)
# Out:
#                                          steaming_data  sentiment_score  \
# 0    program iisma mahasiswi psikologi universitas ...           0.0000
# 1    hooo ept joki palsu sertifikat yaa kalo kait p...          -0.5423
# 2    btw mo cerita kmrn pas volunteer sumpeh rawan ...           0.0000
# 3               akuadn capek ngejar iisma bilang gacha           0.0000
# 4            kalo ga iisma ya s ptln kalo nya sih hehe           0.0000
# ..                                                 ...              ...
# 314                           sleketeprikitiw heboh lu           0.0000
# 315                                 ok ak jd collector           0.2960
# 316                        tabibiba ka tabi beli dmnaa           0.0000
# 317  ken sirkel lolos iisma minimal anak lpdp ndak ...           0.0000
# 318  ehh salah iisma awardee favorit gue ngilang tw...           0.4215
#
#     sentiment
# 0      Netral
# 1     Negatif
# 2      Netral
# 3      Netral
# 4      Netral
# ..        ...
# 314    Netral
# 315   Positif
# 316    Netral
# 317    Netral
# 318   Positif
#
# [319 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sentiment_count = data['sentiment'].value_counts()

sns.set_style('whitegrid')

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Jumlah Analisis Sentimen', fontsize=14, pad=20)
plt.xlabel('Class Sentiment', fontsize=12)
plt.ylabel('Jumlah Tweet', fontsize=12)

for i, count in enumerate(sentiment_count.values):
    ax.text(i, count + 0.10, str(count), ha='center', va='bottom')

plt.show()
# Out:
# <ipython-input-152-346b3b946410>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')

# %%
data.to_csv('labelNLTK.csv', encoding='utf8', index=False)
